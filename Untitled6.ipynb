# %% [markdown]
# Graded Quiz

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading the Data

# %%
data = pd.read_csv ('/content/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'Latin-1')

# %%
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
data.shape
# Out:
# (29917, 12)

# %%
data.isnull().sum()
# Out:
# Area Code         0
# Area              0
# Item Code         0
# Item              0
# Element Code      0
# Element           0
# Unit              0
# Y2014           820
# Y2015           847
# Y2016           838
# Y2017           782
# Y2018           789
# dtype: int64

# %%
mean_value=data['Y2017'].mean()
print(mean_value)
# Out:
# 124.43766020250558

# %%
data['Y2017'].fillna(value=mean_value, inplace=True)
print('Updated Dataframe:')
print(data)
# Out:
# Updated Dataframe:
#        Area Code     Area  Item Code          Item  Element Code  \
# 0              4  Algeria       2501    Population           511
# 1              4  Algeria       2501    Population          5301
# 2              4  Algeria       2901   Grand Total           664
# 3              4  Algeria       2901   Grand Total           674
# 4              4  Algeria       2901   Grand Total           684
# ...          ...      ...        ...           ...           ...
# 29912        123  Liberia       2562  Palm kernels          5611
# 29913        123  Liberia       2562  Palm kernels          5072
# 29914        123  Liberia       2562  Palm kernels          5911
# 29915        123  Liberia       2562  Palm kernels          5301
# 29916        123  Liberia       2562  Palm kernels          5131
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
data.isnull().sum()
# Out:
# Area Code         0
# Area              0
# Item Code         0
# Item              0
# Element Code      0
# Element           0
# Unit              0
# Y2014           820
# Y2015           847
# Y2016           838
# Y2017             0
# Y2018           789
# dtype: int64

# %%
data1 = data["Y2017"].mean()
print(data1)
# Out:
# 124.43766020250558

# %%
data2 = data["Y2017"].std()
print(data2)
# Out:
# 1297.6387803868681

# %%
data.groupby(["Element"]).count()
# Out:
#                                         Area Code  Area  Item Code  Item  \
# Element
# Domestic supply quantity                     2623  2623       2623  2623
# Export Quantity                              2090  2090       2090  2090
# Fat supply quantity (g/capita/day)           2472  2472       2472  2472
# Feed                                          672   672        672   672
# Food                                         2432  2432       2432  2432
# Food supply (kcal/capita/day)                2464  2464       2464  2464
# Food supply quantity (kg/capita/yr)          2416  2416       2416  2416
# Import Quantity                              2541  2541       2541  2541
# Losses                                        957   957        957   957
# Other uses (non-food)                         807   807        807   807
# Processing                                    990   990        990   990
# Production                                   1850  1850       1850  1850
# ...

# %%
print(data.corr())
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.007842     -0.004613  0.001224  0.001755
# Item Code     -0.007842   1.000000     -0.027341  0.022819  0.022062
# Element Code  -0.004613  -0.027341      1.000000  0.024724  0.024858
# Y2014          0.001224   0.022819      0.024724  1.000000  0.998117
# Y2015          0.001755   0.022062      0.024858  0.998117  1.000000
# Y2016          0.002098   0.022062      0.024768  0.997719  0.999066
# Y2017          0.001374   0.022181      0.024740  0.995960  0.997393
# Y2018          0.001778   0.022039      0.025204  0.993559  0.995676
#
#                  Y2016     Y2017     Y2018
# Area Code     0.002098  0.001374  0.001778
# Item Code     0.022062  0.022181  0.022039
# Element Code  0.024768  0.024740  0.025204
# Y2014         0.997719  0.995960  0.993559
# Y2015         0.999066  0.997393  0.995676
# Y2016         1.000000  0.998113  0.996134
# ...

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-ce1543b3be47> in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
data['']
